# %%
import pandas as pd

melb_data = pd.read_csv('data/melb_data_ps.csv', sep=',')
melb_data.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_df = melb_data.copy()
melb_df.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_df = melb_df.drop(['index', 'Coordinates'], axis=1)
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5      3067  ...         1    1     202.0         126.0
# 1  4/02/2016       2.5      3067  ...         1    0     156.0          79.0
# 2  4/03/2017       2.5      3067  ...         2    0     134.0         150.0
# 3  4/03/2017       2.5      3067  ...         2    1      94.0         126.0
# 4  4/06/2016       2.5      3067  ...         1    2     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
total_rooms = melb_df['Rooms'] + melb_df['Bedroom'] + melb_df['Bathroom']
display(total_rooms)
# Out:
# 0         5
# 1         5
# 2         8
# 3         8
# 4         8
#          ..
# 13575    10
# 13576     8
# 13577     8
# 13578     9
# 13579     9
# Length: 13580, dtype: int64

# %%
melb_df['MeanRoomsSquare'] = melb_df['BuildingArea'] / total_rooms
display(melb_df['MeanRoomsSquare'])
# Out:
# 0        25.200000
# 1        15.800000
# 2        18.750000
# 3        15.750000
# 4        17.750000
#            ...
# 13575    12.600000
# 13576    16.625000
# 13577    15.750000
# 13578    17.444444
# 13579    12.444444
# Name: MeanRoomsSquare, Length: 13580, dtype: float64

# %%
diff_area = melb_df['BuildingArea'] - melb_df['Landsize']
sum_area = melb_df['BuildingArea'] + melb_df['Landsize']
melb_df['AreaRatio'] = diff_area/sum_area
display(melb_df['AreaRatio'])
# Out:
# 0       -0.231707
# 1       -0.327660
# 2        0.056338
# 3        0.145455
# 4        0.083969
#            ...
# 13575   -0.676093
# 13576   -0.429185
# 13577   -0.551601
# 13578   -0.693060
# 13579   -0.527426
# Name: AreaRatio, Length: 13580, dtype: float64

# %%
import math
price_square = math.pow(melb_df['Price'], 2)
price_square
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Work\DST\__environment\python-11.ipynb Ячейка 7 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Work/DST/__environment/python-11.ipynb#ch0000006?line=0'>1</a> import math
# ----> <a href='vscode-notebook-cell:/d%3A/Work/DST/__environment/python-11.ipynb#ch0000006?line=1'>2</a> price_square = math.pow(melb_df['Price'], 2)
#       <a href='vscode-notebook-cell:/d%3A/Work/DST/__environment/python-11.ipynb#ch0000006?line=2'>3</a> price_square
#
# File d:\Work\DST\__environment\.env\lib\site-packages\pandas\core\series.py:191, in _coerce_method.<locals>.wrapper(self)
#     189 if len(self) == 1:
#     190     return converter(self.iloc[0])
# --> 191 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'float'>

# %%
customer_df = pd.DataFrame({
    'number': [0, 1, 2, 3, 4],
    'cust_id': [128, 1201, 9832, 4392, 7472],
    'cust_age': [13, 21, 19, 21, 60],
    'cust_sale': [0, 0, 0.2, 0.15, 0.3],
    'cust_year_birth': [2008, 2000, 2002, 2000, 1961],
    'cust_order': [1400, 14142, 900, 1240, 8430]
})
display(customer_df.columns)
# Out:
# Index(['number', 'cust_id', 'cust_age', 'cust_sale', 'cust_year_birth',
#        'cust_order'],
#       dtype='object')

# %%
import pandas as pd


def delete_columns(df:pd.DataFrame, col=[]):
    """
    Напишите функцию delete_columns(df, col=[]), которая удаляет столбцы из DataFrame и возвращает новую таблицу. 
    Если одного из указанных столбцов в таблице не существует, то функция должна возвращать None.
    """
    for c in col:
        if c not in df.columns:
            return None
    return df.drop(col, axis=1)


if __name__ == '__main__':
    customer_df = pd.DataFrame({
        'number': [0, 1, 2, 3, 4],
        'cust_id': [128, 1201, 9832, 4392, 7472],
        'cust_age': [13, 21, 19, 21, 60],
        'cust_sale': [0, 0, 0.2, 0.15, 0.3],
        'cust_year_birth': [2008, 2000, 2002, 2000, 1961],
        'cust_order': [1400, 14142, 900, 1240, 8430]
    })
    columns_for_delete = ['number', 'aa']  # выбранные вами столбцы
    new_df = delete_columns(customer_df, columns_for_delete)
    print(new_df)
# Out:
# ['number', 'aa']
# number Index(['number', 'cust_id', 'cust_age', 'cust_sale', 'cust_year_birth',
#        'cust_order'],
#       dtype='object')
# aa Index(['number', 'cust_id', 'cust_age', 'cust_sale', 'cust_year_birth',
#        'cust_order'],
#       dtype='object')
# None

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})
countries_df['p'] = (countries_df['population'] * 1000000) / countries_df['square']
display(countries_df['p'].mean())
# Out:
# 84.93080566562001

# %%
import pandas as pd

melb_data = pd.read_csv('data/melb_data_ps.csv', sep=',')

display(melb_df['Date'])

melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)
display(melb_df['Date'])
# Out:
# 0         3/12/2016
# 1         4/02/2016
# 2         4/03/2017
# 3         4/03/2017
# 4         4/06/2016
#             ...
# 13575    26/08/2017
# 13576    26/08/2017
# 13577    26/08/2017
# 13578    26/08/2017
# 13579    26/08/2017
# Name: Date, Length: 13580, dtype: object
# 0       2016-12-03
# 1       2016-02-04
# 2       2017-03-04
# 3       2017-03-04
# 4       2016-06-04
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
years_sold = melb_df['Date'].dt.year
print(years_sold)
print('Min year sold:', years_sold.min())
print('Max year sold:', years_sold.max())
print('Mode year sold:', years_sold.mode()[0])
# Out:
# 0        2016
# 1        2016
# 2        2017
# 3        2017
# 4        2016
#          ...
# 13575    2017
# 13576    2017
# 13577    2017
# 13578    2017
# 13579    2017
# Name: Date, Length: 13580, dtype: int64
# Min year sold: 2016
# Max year sold: 2017
# Mode year sold: 2017

# %%
dayofweek_sold = melb_df['Date'].dt.dayofweek
print(dayofweek_sold)
print('Min year sold:', dayofweek_sold.min())
print('Max year sold:', dayofweek_sold.max())
print('Mode year sold:', dayofweek_sold.mode()[0])
# Out:
# 0        5
# 1        3
# 2        5
# 3        5
# 4        5
#         ..
# 13575    5
# 13576    5
# 13577    5
# 13578    5
# 13579    5
# Name: Date, Length: 13580, dtype: int64
# Min year sold: 0
# Max year sold: 6
# Mode year sold: 5

# %%
melb_df['MonthSale'] = melb_df['Date'].dt.month
melb_df['MonthSale'].value_counts(normalize=True)
# Out:
# 5     0.149411
# 7     0.145950
# 9     0.135862
# 6     0.134757
# 8     0.114138
# 11    0.082032
# 4     0.069882
# 3     0.049926
# 12    0.044698
# 10    0.040574
# 2     0.032622
# 1     0.000147
# Name: MonthSale, dtype: float64

# %%
delta_days = melb_df['Date'] - pd.to_datetime('2016-01-01')
display(delta_days.dt.days)
# Out:
# 0        337
# 1         34
# 2        428
# 3        428
# 4        155
#         ...
# 13575    603
# 13576    603
# 13577    603
# 13578    603
# 13579    603
# Name: Date, Length: 13580, dtype: int64

# %%
melb_df['AgeBuilding'] = melb_df['Date'].dt.year - melb_df['YearBuilt']
display(melb_df['AgeBuilding'].describe())
# Out:
# count    13580.000000
# mean        49.745214
# std         29.047316
# min         -2.000000
# 25%         42.000000
# 50%         47.000000
# 75%         56.000000
# max        821.000000
# Name: AgeBuilding, dtype: float64

# %%
melb_df = melb_df.drop('YearBuilt', axis=1)

# %%
dayofweek_sold = melb_df['Date'].dt.dayofweek
melb_data['DayOfSale'] = dayofweek_sold

# %%
melb_data[(melb_data['DayOfSale'] == 5) | (melb_data['DayOfSale'] == 6)]
# Out:
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# 5          5     Abbotsford    129 Charles St      2    h   941000.0      S
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
ufo_df = pd.read_csv('data/ufo.txt', sep=',')
ufo_df['Time'] = pd.to_datetime(ufo_df['Time'], dayfirst=False)
nv_df = ufo_df[ufo_df['State']=='NV']
display(nv_df['Time'].diff().mean())

# ufo_df['Time'].dt.year.mode()
# Out:
# Timedelta('68 days 22:19:49.399293286')

# %%
import pandas as pd

melb_data = pd.read_csv('data/melb_data_ps.csv', sep=',')

display(melb_df.head())
display(melb_df['Address'].nunique())


def get_street_type(address):
    exclude_list = ['N', 'S', 'W', 'E']
    address_list = address.split(' ')
    street_type = address_list[-1]
    if street_type in exclude_list:
        street_type = address_list[-2]
    return street_type


street_types = melb_df['Address'].apply(get_street_type)
display(street_types.nunique())

popular_stypes = street_types.value_counts().nlargest(10).index
melb_df['StreetType'] = street_types.apply(
    lambda x: x if x in popular_stypes else 'other')
display(melb_df['StreetType'].nunique())

melb_df = melb_df.drop('Address', axis=1)
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  CouncilArea  Lattitude  Longtitude  \
# 0 2016-12-03       2.5      3067  ...        Yarra   -37.7996    144.9984
# 1 2016-02-04       2.5      3067  ...        Yarra   -37.8079    144.9934
# 2 2017-03-04       2.5      3067  ...        Yarra   -37.8093    144.9944
# 3 2017-03-04       2.5      3067  ...        Yarra   -37.7969    144.9969
# 4 2016-06-04       2.5      3067  ...        Yarra   -37.8072    144.9941
#
#               Regionname  Propertycount MeanRoomsSquare  AreaRatio  MonthSale  \
# ...

# %%
import pandas as pd

melb_df = pd.read_csv('data/melb_data_ps.csv', sep=',')
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)
melb_df['DayOfSale'] = melb_df['Date'].dt.dayofweek

def dd(date):
    if date in [5, 6]:
        return 1
    else:
        return 0

dow = melb_df['DayOfSale'].apply(dd)

melb_df['Weekend'] = dow

popular_s = melb_df['SellerG'].value_counts().nlargest(10).index

melb_df['SellerGG'] = melb_df['SellerG'].apply(
    lambda x: x if x in popular_s else 'other')

melb_df[melb_df['SellerGG'] == 'Nelson']['Price'].min()/melb_df[melb_df['SellerGG'] == 'other']['Price'].min()
# Out:
# 2.0

# %%
import pandas as pd
import re


def get_experience(arg):
    """
    Напишите функцию get_experience(arg), аргументом которой является строка столбца с опытом работы. 
    Функция должна возвращать опыт работы в месяцах. Не забудьте привести результат к целому числу.
    """
    y = re.findall(r'([0-9]+) (лет|год)', arg)
    if y: 
        y = int(y[0][0]) 
    else: 
        y =0
    m = re.findall(r'([0-9]+) месяц', arg)
    if m:
        m = int(m[0])
    else:
        m = 0
    return y * 12 + m



if __name__ == '__main__':
    experience_col = pd.Series([
        'Опыт работы 8 лет 3 месяца',
        'Опыт работы 3 года 5 месяцев',
        'Опыт работы 1 год 9 месяцев',
        'Опыт работы 3 месяца',
        'Опыт работы 6 лет'
    ])
    experience_month = experience_col.apply(get_experience)
    print(experience_month)
# Out:
# 0    99
# 1    41
# 2    21
# 3     3
# 4    72
# dtype: int64

# %%
import re

s = [
    'Опыт работы 8 лет 3 месяца',
    'Опыт работы 3 года 5 месяцев',
    'Опыт работы 1 год 9 месяцев',
    'Опыт работы 1 одг 9 месяцев',
    'Опыт работы 3 месяца',
    'Опыт работы 6 лет'
]

for _s in s:
    y = re.findall(r'([0-9]+) (лет|год)', _s)
    if y: print(y[0][0])
    m = re.findall(r'([0-9]+) месяц', _s)
    if m: print(m[0])
    print('')
# Out:
# 8
# 3
#
# 3
# 5
#
# 1
# 9
#
# 9
#
# 3
#
# 6

# %%
import pandas as pd

melb_df = pd.read_csv('data/melb_data_ps.csv', sep=',')


# создаём пустой список
unique_list = []
# пробегаемся по именам столбцов в таблице
for col in melb_df.columns:
    # создаём кортеж (имя столбца, число уникальных значений)
    item = (col, melb_df[col].nunique(), melb_df[col].dtype)
    # добавляем кортеж в список
    unique_list.append(item)
# создаём вспомогательную таблицу и сортируем её
unique_counts = pd.DataFrame(
    unique_list,
    columns=['Column_Name', 'Num_Unique', 'Type']
).sort_values(by='Num_Unique',  ignore_index=True)
# выводим её на экран
display(unique_counts)
# Out:
#       Column_Name  Num_Unique     Type
# 0            Type           3   object
# 1          Method           5   object
# 2      Regionname           8   object
# 3           Rooms           9    int64
# 4        Bathroom           9    int64
# 5             Car          11    int64
# 6         Bedroom          12    int64
# 7     CouncilArea          33   object
# 8            Date          58   object
# 9       YearBuilt         144    int64
# 10       Postcode         198    int64
# 11       Distance         202  float64
# 12        SellerG         268   object
# 13  Propertycount         311    int64
# 14         Suburb         314   object
# 15   BuildingArea         602  float64
# 16       Landsize        1448  float64
# 17          Price        2204  float64
# 18      Lattitude        6503  float64
# 19     Longtitude        7063  float64
# 20    Coordinates       13097   object
# 21        Address       13378   object
# 22          index       13580    int64

# %%
import pandas as pd

melb_df = pd.read_csv('data/melb_data_ps.csv', sep=',')


cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] # список столбцов, которые мы не берём во внимание

max_unique_count = 150 # задаём максимальное число уникальных категорий

for col in melb_df.columns: # цикл по именам столбцов
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude: # проверяем условие
        melb_df[col] = melb_df[col].astype('category') # преобразуем тип столбца

melb_df['Type'] = melb_df['Type'].cat.rename_categories({
    'u': 'unit',
    't': 'townhouse',
    'h': 'house'
})


melb_df['Type'] = melb_df['Type'].cat.add_categories('flat')
new_houses_types = pd.Series(['unit', 'house', 'flat', 'flat', 'house'])
new_houses_types = new_houses_types.astype(melb_df['Type'].dtype)

display(melb_df.info())

popular_suburb = melb_df['Suburb'].value_counts().nlargest(150).index
melb_df['Suburb'] = melb_df['Suburb'].apply(
    lambda x: x if x in popular_suburb else 'other')

display(melb_df['Suburb'].nunique())
melb_df['Suburb'] = melb_df['Suburb'].astype('category')

display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  category
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  category
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  category
# ...

# %%
import pandas as pd

c_df = pd.read_csv('data/citibike-tripdata.csv', sep=',')

# starttime — время начала поездки (дата, время);
# stoptime — время окончания поездки (дата, время);
# start station id — идентификатор стартовой стоянки;
# start station name — название стартовой стоянки;
# start station latitude, start station longitude — географическая широта и долгота стартовой стоянки;
# end station id — идентификатор конечной стоянки;
# end station name — название конечной стоянки;
# end station latitude, end station longitude — географическая широта и долгота конечной стоянки;
# bikeid — идентификатор велосипеда;
# usertype — тип пользователя (Customer — клиент с подпиской на 24 часа или на три дня, Subscriber — подписчик с годовой арендой велосипеда);
# birth year — год рождения клиента;
# gender — пол клиента (0 — неизвестный, 1 — мужчина, 2 — женщина).

def get_time_of_day(val:int):
    if 0 <= val <= 6:
        return 'night'
    if 6 < val <= 12:
        return 'morning'
    if 12 < val <= 18:
        return 'day'
    if 18 < val <= 23:
        return 'evening'

# display(c_df.info())
# display(c_df[c_df['usertype'] == 'Subscriber'])
# display(c_df[c_df['gender'] == 1])
c_df = c_df.drop(['start station id', 'end station id'], axis=1)
# display(c_df.shape)
c_df['age'] = 2018 - c_df['birth year']
# display(c_df[c_df['age'] > 60])
c_df['starttime'] = pd.to_datetime(c_df['starttime'])
c_df['stoptime'] = pd.to_datetime(c_df['stoptime'])
c_df['trip duration'] = c_df['stoptime'] - c_df['starttime']
# display(c_df['trip duration'].mean().seconds)
dow = c_df['starttime'].dt.dayofweek
c_df['weekend'] = dow.apply(
    lambda x: 1 if x in [5, 6] else 0)
# display(c_df['weekend'].sum())
h = c_df['starttime'].dt.hour
c_df['time of day'] = h.apply(get_time_of_day)
display(round(c_df[c_df['time of day'] == 'day'].shape[0] / c_df[c_df['time of day'] == 'night'].shape[0]))
# Out:
# 9
